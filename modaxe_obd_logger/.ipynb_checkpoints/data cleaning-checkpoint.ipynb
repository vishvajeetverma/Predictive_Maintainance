# %%
import pandas as pd

# Load the raw data file
file_path = "/home/kaifalam/vishvajeet_verma/modaxe_obd_logger/data/2025-10-17 12-55-25.csv"
df = pd.read_csv(file_path, sep=';', engine='python')

# Display structure and a preview
print("Columns in the file:")
print(df.columns)

print("\nShape of the data (rows, columns):", df.shape)

print("\nFirst 50 rows:")
display(df.head(50))
# Out:
# Columns in the file:
# Index(['SECONDS', 'PID', 'VALUE', 'UNITS', 'LATITUDE', 'LONGTITUDE',
#        'Unnamed: 6'],
#       dtype='object')
#
# Shape of the data (rows, columns): (6500, 7)
#
# First 50 rows:
#          SECONDS                                PID       VALUE UNITS  \
# 0   46537.184014                Average speed (GPS)    0.000000  km/h
# 1   46537.184014                        Speed (GPS)    0.000000  km/h
# 2   46537.192014                     Altitude (GPS)  874.299988     m
# 3   46537.193014                     Altitude (GPS)  874.299988     m
# 4   46537.197014                     Altitude (GPS)  874.299988     m
# 5   46537.197014                Average speed (GPS)    0.000000  km/h
# 6   46537.197014                        Speed (GPS)    0.000000  km/h
# 7   46537.198014                     Altitude (GPS)  874.299988     m
# 8   46537.198014                Average speed (GPS)    0.000000  km/h
# 9   46537.198014                        Speed (GPS)    0.000000  km/h
# 10  46541.956014                Average speed (GPS)    0.000000  km/h
# 11  46541.956014                        Speed (GPS)    0.000000  km/h
# 12  46541.957014                     Altitude (GPS)  872.000000     m
# 13  46541.957014                     Altitude (GPS)  872.000000     m
# 14  46541.957014                Average speed (GPS)    0.000000  km/h
# 15  46541.957014                        Speed (GPS)    0.000000  km/h
# 16  46542.011014                     Altitude (GPS)  874.299988     m
# 17  46542.011014                Average speed (GPS)    0.000000  km/h
# 18  46542.011014                        Speed (GPS)    0.000000  km/h
# 19  46542.431014                     Altitude (GPS)  873.700012     m
# 20  46542.432014                     Altitude (GPS)  873.700012     m
# 21  46542.432014                     Altitude (GPS)  873.700012     m
# 22  46542.432014                Average speed (GPS)    0.000000  km/h
# 23  46542.432014                Average speed (GPS)    0.000000  km/h
# 24  46542.432014                        Speed (GPS)    0.000000  km/h
# 25  46542.432014                        Speed (GPS)    0.000000  km/h
# 26  46547.291014                     Altitude (GPS)  863.000000     m
# 27  46548.605014                Average speed (GPS)    0.000000  km/h
# 28  46548.605014                        Speed (GPS)    0.000000  km/h
# 29  46548.606014                     Altitude (GPS)  873.700012     m
# 30  46548.609014                     Altitude (GPS)  874.299988     m
# 31  46548.609014                     Altitude (GPS)  874.299988     m
# 32  46548.609014                Average speed (GPS)    0.000000  km/h
# 33  46548.609014                Average speed (GPS)    0.000000  km/h
# 34  46548.609014                        Speed (GPS)    0.000000  km/h
# 35  46548.609014                        Speed (GPS)    0.000000  km/h
# 36  46548.611014                     Altitude (GPS)  874.299988     m
# 37  46548.611014                Average speed (GPS)    0.000000  km/h
# 38  46548.611014                        Speed (GPS)    0.000000  km/h
# 39  46548.616014                     Altitude (GPS)  874.299988     m
# 40  46548.616014                Average speed (GPS)    0.000000  km/h
# 41  46548.616014                        Speed (GPS)    0.000000  km/h
# 42  46548.617014                     Altitude (GPS)  874.299988     m
# 43  46549.181014                 OBD Module Voltage   14.000000     V
# 44  46549.339014       Calculated engine load value   36.078431     %
# 45  46549.437014         Engine coolant temperature   74.000000     ℃
# 46  46549.509014                   Calculated boost   -0.917364   psi
# 47  46549.509014  Intake manifold absolute pressure   13.778585   psi
# 48  46549.602014                         Engine RPM  824.000000   rpm
# 49  46549.602014                   Engine RPM x1000    0.800000   rpm
#
#      LATITUDE  LONGTITUDE  Unnamed: 6
# 0   13.015782   77.565621         NaN
# 1   13.015782   77.565621         NaN
# 2   13.015782   77.565621         NaN
# 3   13.015782   77.565621         NaN
# 4   13.015782   77.565621         NaN
# 5   13.015782   77.565621         NaN
# 6   13.015782   77.565621         NaN
# 7   13.015782   77.565621         NaN
# 8   13.015782   77.565621         NaN
# 9   13.015782   77.565621         NaN
# 10  13.015782   77.565621         NaN
# 11  13.015782   77.565621         NaN
# 12  13.015782   77.565621         NaN
# 13  13.015782   77.565621         NaN
# 14  13.015782   77.565621         NaN
# 15  13.015782   77.565621         NaN
# 16  13.015782   77.565621         NaN
# 17  13.015782   77.565621         NaN
# 18  13.015782   77.565621         NaN
# 19  13.015922   77.565655         NaN
# 20  13.015922   77.565655         NaN
# 21  13.015922   77.565655         NaN
# 22  13.015922   77.565655         NaN
# 23  13.015922   77.565655         NaN
# 24  13.015922   77.565655         NaN
# 25  13.015922   77.565655         NaN
# 26  13.015813   77.565668         NaN
# 27  13.015813   77.565668         NaN
# 28  13.015813   77.565668         NaN
# 29  13.015813   77.565668         NaN
# 30  13.015813   77.565668         NaN
# 31  13.015813   77.565668         NaN
# 32  13.015813   77.565668         NaN
# 33  13.015813   77.565668         NaN
# 34  13.015813   77.565668         NaN
# 35  13.015813   77.565668         NaN
# 36  13.015813   77.565668         NaN
# 37  13.015813   77.565668         NaN
# 38  13.015813   77.565668         NaN
# 39  13.015813   77.565668         NaN
# 40  13.015813   77.565668         NaN
# 41  13.015813   77.565668         NaN
# 42  13.015770   77.565619         NaN
# 43  13.015770   77.565619         NaN
# 44  13.015770   77.565619         NaN
# 45  13.015770   77.565619         NaN
# 46  13.015770   77.565619         NaN
# 47  13.015770   77.565619         NaN
# 48  13.015770   77.565619         NaN
# 49  13.015770   77.565619         NaN

# %%
print("Exact column names:\n")
for i, col in enumerate(df.columns):
    print(f"{i+1}. '{col}'")
# Out:
# Exact column names:
#
# 1. 'SECONDS'
# 2. 'PID'
# 3. 'VALUE'
# 4. 'UNITS'
# 5. 'LATITUDE'
# 6. 'LONGTITUDE'
# 7. 'Unnamed: 6'

# %%
# Check the first 10 unique PIDs to understand data variety
print("Unique PIDs:\n", df['PID'].unique()[:10])

# Check how the SECONDS values look (to decide conversion to timestamp)
print("\nSample SECONDS values:\n", df['SECONDS'].head(10))

# Check for missing values
print("\nMissing values per column:\n", df.isnull().sum())
# Out:
# Unique PIDs:
#  ['Average speed (GPS)' 'Speed (GPS)' 'Altitude (GPS)' 'OBD Module Voltage'
#  'Calculated engine load value' 'Engine coolant temperature'
#  'Calculated boost' 'Intake manifold absolute pressure' 'Engine RPM'
#  'Engine RPM x1000']
#
# Sample SECONDS values:
#  0    46537.184014
# 1    46537.184014
# 2    46537.192014
# 3    46537.193014
# 4    46537.197014
# 5    46537.197014
# 6    46537.197014
# 7    46537.198014
# 8    46537.198014
# 9    46537.198014
# Name: SECONDS, dtype: float64
#
# Missing values per column:
#  SECONDS          0
# PID              0
# VALUE            0
# UNITS            0
# LATITUDE         0
# LONGTITUDE       0
# Unnamed: 6    6500
# dtype: int64

# %%
print("Exact column names:\n")
for i, col in enumerate(df.columns):
    print(f"{i+1}. '{col}'")
# Out:
# Exact column names:
#
# 1. 'SECONDS'
# 2. 'PID'
# 3. 'VALUE'
# 4. 'UNITS'
# 5. 'LATITUDE'
# 6. 'LONGTITUDE'
# 7. 'Unnamed: 6'

# %%
import pandas as pd
from datetime import datetime, timedelta

# 1️⃣ Drop unwanted unnamed column
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# 2️⃣ Define your actual recording start date
base_date = datetime(2025, 10, 17, 0, 0, 0)  # 17 Oct 2025 midnight

# 3️⃣ Convert 'SECONDS' → timestamps relative to that base date
start_time = df['SECONDS'].iloc[0]
df['timestamp'] = base_date + pd.to_timedelta(df['SECONDS'] - start_time, unit='s')

# 4️⃣ Build expanded DataFrame (no collapsing)
rows = []
for _, row in df.iterrows():
    new_row = {
        'timestamp': row['timestamp'],
        row['PID']: row['VALUE'],
        'LATITUDE': row['LATITUDE'],
        'LONGITUDE': row['LONGTITUDE']
    }
    rows.append(new_row)

pivot_df = pd.DataFrame(rows)

# 5️⃣ Ensure all PIDs are present
all_pids = sorted(df['PID'].unique().tolist())
pivot_df = pivot_df.reindex(columns=['timestamp'] + all_pids + ['LATITUDE', 'LONGITUDE'])

# 6️⃣ Display result
print("✅ Data transformed successfully with correct timestamps (2025).")
print("Shape of transformed data:", pivot_df.shape)
display(pivot_df.head(10))
# Out:
# ✅ Data transformed successfully with correct timestamps (2025).
# Shape of transformed data: (6500, 30)
#                 timestamp  Altitude (GPS)  Average speed  Average speed (GPS)  \
# 0 2025-10-17 00:00:00.000             NaN            NaN                  0.0
# 1 2025-10-17 00:00:00.000             NaN            NaN                  NaN
# 2 2025-10-17 00:00:00.008      874.299988            NaN                  NaN
# 3 2025-10-17 00:00:00.009      874.299988            NaN                  NaN
# 4 2025-10-17 00:00:00.013      874.299988            NaN                  NaN
# 5 2025-10-17 00:00:00.013             NaN            NaN                  0.0
# 6 2025-10-17 00:00:00.013             NaN            NaN                  NaN
# 7 2025-10-17 00:00:00.014      874.299988            NaN                  NaN
# 8 2025-10-17 00:00:00.014             NaN            NaN                  0.0
# 9 2025-10-17 00:00:00.014             NaN            NaN                  NaN
#
#    Barometric pressure  Calculated boost  Calculated engine load value  \
# 0                  NaN               NaN                           NaN
# 1                  NaN               NaN                           NaN
# 2                  NaN               NaN                           NaN
# 3                  NaN               NaN                           NaN
# 4                  NaN               NaN                           NaN
# 5                  NaN               NaN                           NaN
# 6                  NaN               NaN                           NaN
# 7                  NaN               NaN                           NaN
# 8                  NaN               NaN                           NaN
# 9                  NaN               NaN                           NaN
#
#    Calculated instant fuel rate  Distance traveled with MIL on  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN
#
#    Distance travelled  ...  Intake air temperature  \
# 0                 NaN  ...                     NaN
# 1                 NaN  ...                     NaN
# 2                 NaN  ...                     NaN
# 3                 NaN  ...                     NaN
# 4                 NaN  ...                     NaN
# 5                 NaN  ...                     NaN
# 6                 NaN  ...                     NaN
# 7                 NaN  ...                     NaN
# 8                 NaN  ...                     NaN
# 9                 NaN  ...                     NaN
#
#    Intake manifold absolute pressure  MAF air flow rate  OBD Module Voltage  \
# 0                                NaN                NaN                 NaN
# 1                                NaN                NaN                 NaN
# 2                                NaN                NaN                 NaN
# 3                                NaN                NaN                 NaN
# 4                                NaN                NaN                 NaN
# 5                                NaN                NaN                 NaN
# 6                                NaN                NaN                 NaN
# 7                                NaN                NaN                 NaN
# 8                                NaN                NaN                 NaN
# 9                                NaN                NaN                 NaN
#
#    Power from MAF  Speed (GPS)  Vehicle acceleration  Vehicle speed  \
# 0             NaN          NaN                   NaN            NaN
# 1             NaN          0.0                   NaN            NaN
# 2             NaN          NaN                   NaN            NaN
# 3             NaN          NaN                   NaN            NaN
# 4             NaN          NaN                   NaN            NaN
# 5             NaN          NaN                   NaN            NaN
# 6             NaN          0.0                   NaN            NaN
# 7             NaN          NaN                   NaN            NaN
# 8             NaN          NaN                   NaN            NaN
# 9             NaN          0.0                   NaN            NaN
#
#     LATITUDE  LONGITUDE
# 0  13.015782  77.565621
# 1  13.015782  77.565621
# 2  13.015782  77.565621
# 3  13.015782  77.565621
# 4  13.015782  77.565621
# 5  13.015782  77.565621
# 6  13.015782  77.565621
# 7  13.015782  77.565621
# 8  13.015782  77.565621
# 9  13.015782  77.565621
#
# [10 rows x 30 columns]

# %%
# Get sorted unique PIDs
all_pids = sorted(df['PID'].unique().tolist())

# Display them horizontally (landscape)
print("Total number of unique PIDs:", len(all_pids))
print("\nList of PIDs:\n")
print(" | ".join(all_pids))
# Out:
# Total number of unique PIDs: 27
#
# List of PIDs:
#
# Altitude (GPS) | Average speed | Average speed (GPS) | Barometric pressure | Calculated boost | Calculated engine load value | Calculated instant fuel rate | Distance traveled with MIL on | Distance travelled | Distance travelled (total) | Engine RPM | Engine RPM x1000 | Engine coolant temperature | Fuel rail press. | Fuel used | Fuel used (total) | Fuel used price | Fuel used price (total) | Instant engine power (based on fuel consumption) | Intake air temperature | Intake manifold absolute pressure | MAF air flow rate | OBD Module Voltage | Power from MAF | Speed (GPS) | Vehicle acceleration | Vehicle speed

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/kaifalam/.local/lib/python3.13/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/kaifalam/miniconda3/lib/python3.13/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kaifalam/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/kaifalam/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 27.9 MB/s eta 0:00:0000:01
# Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Downloading pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 24.6 MB/s eta 0:00:00a 0:00:01
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5

# %%
import matplotlib.pyplot as plt

# 1️⃣ List of important PIDs to keep
important_pids = [
    "Engine RPM",
    "Calculated engine load value",
    "Intake manifold absolute pressure",
    "MAF air flow rate",
    "Engine coolant temperature",
    "Vehicle speed",
    "Fuel rail press.",
    "Calculated instant fuel rate",
    "Instant engine power (based on fuel consumption)",
    "OBD Module Voltage",
    "Power from MAF",
    "LATITUDE",
    "LONGTITUDE"
]

# 2️⃣ Filter columns
df_reduced = df[["timestamp"] + [pid for pid in important_pids if pid in df.columns]]

print("Filtered data shape:", df_reduced.shape)
print("\nFirst 10 rows of reduced dataset:")
display(df_reduced.head(10))

# 3️⃣ Plot a few parameters vs timestamp
plt.figure(figsize=(12,6))
plt.plot(df_reduced["timestamp"], df_reduced["Engine RPM"], label="Engine RPM")
plt.plot(df_reduced["timestamp"], df_reduced["Engine coolant temperature"], label="Coolant Temp")
plt.plot(df_reduced["timestamp"], df_reduced["Vehicle speed"], label="Vehicle Speed")
plt.xlabel("Timestamp")
plt.ylabel("Values")
plt.legend()
plt.title("Key Parameters over Time")
plt.show()
# Out:
# Filtered data shape: (6500, 3)
#
# First 10 rows of reduced dataset:
#                 timestamp   LATITUDE  LONGTITUDE
# 0 2025-10-17 00:00:00.000  13.015782   77.565621
# 1 2025-10-17 00:00:00.000  13.015782   77.565621
# 2 2025-10-17 00:00:00.008  13.015782   77.565621
# 3 2025-10-17 00:00:00.009  13.015782   77.565621
# 4 2025-10-17 00:00:00.013  13.015782   77.565621
# 5 2025-10-17 00:00:00.013  13.015782   77.565621
# 6 2025-10-17 00:00:00.013  13.015782   77.565621
# 7 2025-10-17 00:00:00.014  13.015782   77.565621
# 8 2025-10-17 00:00:00.014  13.015782   77.565621
# 9 2025-10-17 00:00:00.014  13.015782   77.565621
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Engine RPM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 29
#      27 # 3️⃣ Plot a few parameters vs timestamp
#      28 plt.figure(figsize=(12,6))
# ---> 29 plt.plot(df_reduced["timestamp"], df_reduced["Engine RPM"], label="Engine RPM")
#      30 plt.plot(df_reduced["timestamp"], df_reduced["Engine coolant temperature"], label="Coolant Temp")
#      31 plt.plot(df_reduced["timestamp"], df_reduced["Vehicle speed"], label="Vehicle Speed")
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Engine RPM'
